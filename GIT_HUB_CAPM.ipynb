# %% [markdown]
# FOLLOW THESE STEPS TO RUN THIS WORKBOOK
#
#
# 1. Run all cells by choosing the commands as shown in the picture that can be found at the top of this workbook in the menu bar:
#  ![image.png](data:image/png;base64,...)
#
# 3.  Next, collapse all code by choosing the commands as shown in the picture that can be found at the top of this workbook in the menu bar:
# ![image.png](data:image/png;base64,...)
#
# 3.  Additionally, towards the end of the workbook, you'll find interactive graphs and charts that respond as you hover your mouse over them.

# %%
# !pip install pycaret
# !pip install yfinance
import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt
# !pip install plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
# !pip install dash
from dash import Dash, dcc, html, Input, Output
from sklearn.model_selection import train_test_split
from sklearn import linear_model, tree, neighbors
import plotly.graph_objects as go
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from plotly.subplots import make_subplots
from sklearn.preprocessing import PolynomialFeatures
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Requirement already satisfied: pycaret in /srv/conda/envs/notebook/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (8.37.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (4.67.3)
# Requirement already satisfied: numpy<1.27,>=1.21 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.0.7)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.64.0)
# Requirement already satisfied: requests>=2.27.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (7.1.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (6.3.0)
# Requirement already satisfied: kaleido>=0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.14.6)
# Requirement already satisfied: sktime==0.26.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: wurlitzer in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (12.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas<2.2.0->pycaret) (2025.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.5)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: exceptiongroup in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.14)
# Requirement already satisfied: comm>=0.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: choreographer>=1.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaleido>=0.2.1->pycaret) (3.11.7)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.5.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from numba>=0.55.0->pycaret) (0.46.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly>=5.14.0->pycaret) (2.15.0)
# Requirement already satisfied: dash>=2.11.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.0.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: retrying in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pmdarima>=2.0.4->pycaret) (3.2.4)
# Requirement already satisfied: urllib3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pmdarima>=2.0.4->pycaret) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (9.0.2)
# Requirement already satisfied: iniconfig>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: tomli>=1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.27.1->pycaret) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure_eval in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: yfinance in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: plotly in /srv/conda/envs/notebook/lib/python3.10/site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly) (2.15.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly) (25.0)
# Requirement already satisfied: dash in /srv/conda/envs/notebook/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (6.3.0)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dash) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (2.15.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->dash) (2025.10.5)

# %% [markdown]
# ##CODE WITHIN THIS WORKBOOK WAS CREATED THROUGH PERONAL UNDERSTANDING AND ALSO THE ASSISTANCE OF MICROSOFT COPILOT AND CHAT GPT 3.5 SNIPPETS WERE CREATED AND ITERATED OVER AND OVER TO PRODUCE A CUSTOMIZED OUTPUT
#
# ##THE DOWNLOADED RETURNS WERE NORMALIZED
#
# **Normalized Returns: Comparing Exxon and the S&P 500**
#
# Normalizing is similar to taking two objects that are vastly different in weight and converting them to objects that are similar and can be weighed on the same scale.  There are mathematical techniques which make this conversion possible.
#
# The below code will normailize the returns and put them into a chart.

# %%
# Define start and end dates
# !pip install seaborn
plt.rcParams['font.family'] = 'serif'
start = datetime.datetime(2023, 1, 1)
end = datetime.datetime(2026, 3, 8)

# Fetch data for S&P 500 (SPX) from Yahoo Finance using yfinance
df_spx = yf.download('^GSPC', start=start, end=end)  # Use '^GSPC' instead of 'SPX'
df_xom = yf.download('XOM', start=start, end=end)  # Use XOM
# Calculate daily returns
df_xom['Daily_Return'] = df_xom['Open'].pct_change()
df_spx['Daily_Return'] = df_spx['Open'].pct_change()

# Normalize returns
df_xom['Normalized_Return'] = (1 + df_xom['Daily_Return']).cumprod()
df_spx['Normalized_Return'] = (1 + df_spx['Daily_Return']).cumprod()

#Remove Null Values Replace with Mode
for column in df_spx.columns:
    df_spx[column].fillna(df_spx[column].mode()[0], inplace=True)
for column in df_xom.columns:
    df_xom[column].fillna(df_xom[column].mode()[0], inplace=True)

# Plot normalized returns
plt.figure(figsize=(10, 6))
plt.plot(df_xom.index, df_xom['Normalized_Return'], label='XOM')
plt.plot(df_spx.index, df_spx['Normalized_Return'], label='SPX')
plt.xlabel('Date')
plt.ylabel('Normalized Return')
plt.title('Normalized Returns: XOM vs. SPX')
plt.legend()
plt.show()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Requirement already satisfied: seaborn in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ##For those familiar with statistics, executing the following code will generate a chart for a high-level overview of the S&P.

# %%
df_spx.describe()
# Out:
# Price         Close         High          Low         Open        Volume  \
# Ticker        ^GSPC        ^GSPC        ^GSPC        ^GSPC         ^GSPC
# count   4573.000000  4573.000000  4573.000000  4573.000000  4.573000e+03
# mean    2777.609308  2792.475796  2760.501049  2777.117579  4.171275e+09
# std     1570.432053  1577.246204  1562.437380  1570.183105  1.132853e+09
# min      676.530029   695.270020   666.789978   679.280029  0.000000e+00
# 25%     1402.599976  1407.750000  1394.459961  1402.550049  3.448250e+09
# 50%     2280.899902  2295.909912  2272.439941  2288.540039  3.922470e+09
# 75%     3940.590088  3969.620117  3911.909912  3938.679932  4.666470e+09
# max     6978.600098  7002.279785  6963.459961  7002.000000  1.145623e+10
#
# Price  Daily_Return Normalized_Return
# Ticker
# count   4573.000000       4573.000000
# mean       0.000382          1.891752
# std        0.011586          1.069683
# min       -0.087119          0.462734
# 25%       -0.003940          0.955353
# 50%        0.000865          1.558983
# 75%        0.005653          2.683079
# max        0.106712          4.769852

# %% [markdown]
# ##The next cell can be run to get the same statistics for Exxon.

# %%
df_xom.describe()
# Out:
# Price         Close         High          Low         Open        Volume  \
# Ticker          XOM          XOM          XOM          XOM           XOM
# count   4573.000000  4573.000000  4573.000000  4573.000000  4.573000e+03
# mean      60.670960    61.226868    60.088915    60.657382  1.901052e+07
# std       24.158061    24.384065    23.930183    24.153873  1.064019e+07
# min       23.985264    24.938573    22.963316    24.808922  3.851300e+06
# 25%       46.216679    46.649430    45.751866    46.196118  1.185810e+07
# 50%       53.604279    53.999100    53.251904    53.654649  1.614540e+07
# 75%       60.991512    61.283914    60.609931    60.979116  2.296930e+07
# max      154.529999   159.610001   153.029999   159.350006  1.180235e+08
#
# Price  Daily_Return Normalized_Return
# Ticker
# count   4573.000000       4573.000000
# mean       0.000354          1.235681
# std        0.017119          0.492567
# min       -0.177062          0.505214
# 25%       -0.007758          0.940748
# 50%        0.000579          1.092645
# 75%        0.008674          1.241913
# max        0.156395          3.245038

# %%
# Define start and end dates
plt.rcParams['font.family'] = 'serif'
start = datetime.datetime(2023, 1, 1)
end = datetime.datetime(2026, 3, 8)
from sklearn.impute import SimpleImputer

# Fetch data for XOM from Yahoo Finance using yfinance
#df_spx_gradient = yf.download('^GSPC', start=start, end=end)  # Use '^GSPC' instead of 'SPX'
df_xom_gradient = yf.download('XOM', start=start, end=end)  # Use XOM
# Calculate daily returns
df_xom_gradient['Daily_Return'] = df_xom['Open'].pct_change()
#df_spx_gradient['Daily_Return'] = df_spx['Open'].pct_change()

# Normalize returns
df_xom_gradient['Normalized_Return'] = (1 + df_xom_gradient['Daily_Return']).cumprod()
#df_spx_gradient['Normalized_Return'] = (1 + df_spx['Daily_Return']).cumprod()

#Remove Null Values Replace with Mode
#for column in df_xom_gradient.columns:
    #df_spx_gradient[column].fillna(df_spx[column].mode()[0], inplace=True)
for column in df_xom_gradient.columns:
    df_xom[column].fillna(df_xom[column].mode()[0], inplace=True)

# Plot normalized returns
plt.figure(figsize=(10, 6))
plt.plot(df_xom_gradient.index, df_xom['Normalized_Return'], label='XOM')
#plt.plot(df_spx_gradient.index, df_spx_gradient['Normalized_Return'], label='SPX')
plt.xlabel('Date')
plt.ylabel('Normalized Return')
plt.title('Normalized Returns: XOM')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CAPM Analysis: Comparing Exxon and S&P 500
#
# Next you will discover the Beta of Exxon which is the risk of Exxon stock in relation to the overall market.

# %%
# Define start and end dates
start = datetime.datetime(2023, 1, 1)
end = datetime.datetime(2026, 3, 8)

# Fetch data for Exxon (XOM) and S&P 500 (SPY) from Yahoo Finance using yfinance
df_xom = yf.download('XOM', start=start, end=end)
df_spx = yf.download('^GSPC', start=start, end=end)

# Calculate daily returns for Exxon and the S&P 500
df_xom['Daily_Return'] = df_xom['Close'].pct_change(1)
df_spx['Daily_Return'] = df_spx['Close'].pct_change(1)

# Drop NaN values
df_xom.dropna(inplace=True)
df_spx.dropna(inplace=True)

# Perform linear regression to estimate beta coefficient (market risk) for Exxon
slope, intercept, r_value, p_value, std_err = stats.linregress(df_spx['Daily_Return'], df_xom['Daily_Return'])

# Plot CAPM regression line
plt.scatter(df_spx['Daily_Return'], df_xom['Daily_Return'], alpha=0.5)
plt.plot(df_spx['Daily_Return'], intercept + slope * df_spx['Daily_Return'], color='red', label='CAPM Line')
plt.xlabel('Market Return (S&P 500)')
plt.ylabel('Stock Return (Exxon)')
plt.title('CAPM: Exxon vs. S&P 500')
plt.legend()
plt.grid(True)
plt.show()

# Output beta coefficient
print("Beta (market risk) for Exxon:", slope)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Beta (market risk) for Exxon: 0.877253472162631

# %% [markdown]
# **K-means clustering** K-means clustering is a very useful machine learning tool. The most simplistic explanation is that it allows the creation of a model that will break apart data based on a chosen number of datapoints (centroids) and begin to calculate the mean of each datapoint. The data is stripped of all descriptions and the model itself operates based on unsupervised learning. After a multitude of calculations the datapoints will begin to group into clusters based upon their mean which can than be evaluated to assimilate them into like values. A similar concept is Principal Component Analysis (PCA). Think of PCA like taking a tall stack of pieces to a complex puzzle and putting them together as a flat surface that creates a meaningful image which can than be interpreted. All pieces are not used in order to capture the image. Just those that provide the clearest definition. The mathematical computations are involved and can be studied by the reader who may be interested in understanding the detailed nuances of the calculations. In the below K-means example one cluster may represent market volume while another may represent the the change in normalized returns etc.
#
# Source of Undersatnding and Writing based on concepts of (Dr. Caroline Uhler, MIT Class Lectures, 2023).

# %%
# Define start and end dates
start = datetime.datetime(2023, 1, 1)
end = datetime.datetime(2026, 3, 8)

# Fetch data for S&P 500 (SPX) from Yahoo Finance using yfinance
df_spx = yf.download('^GSPC', start=start, end=end)  # Use '^GSPC' instead of 'SPX'
df_xom = yf.download('XOM', start=start, end=end)  # Use XOM
# Calculate daily returns
df_xom['Daily_Return'] = df_xom['Open'].pct_change()
df_spx['Daily_Return'] = df_spx['Open'].pct_change()

# Normalize returns
df_xom['Normalized_Return'] = (1 + df_xom['Daily_Return']).cumprod()
df_spx['Normalized_Return'] = (1 + df_spx['Daily_Return']).cumprod()

#Remove Null Values Replace with Mode
for column in df_spx.columns:
    df_spx[column].fillna(df_spx[column].mode()[0], inplace=True)
for column in df_xom.columns:
    df_xom[column].fillna(df_xom[column].mode()[0], inplace=True)
from sklearn.cluster import KMeans


# Example DataFrames df_spx and df_xom
# Assuming df_spx and df_xom are already defined and contain the necessary data

# Concatenate the two DataFrames vertically
df_concatenated = pd.concat([df_spx, df_xom])

# Assuming you have already selected the features you want to use for clustering
features = ['Daily_Return', 'Normalized_Return']  # Replace 'feature1', 'feature2', ... with actual feature names

# Prepare the data for clustering
X = df_concatenated[features]

# Define the number of clusters
num_clusters = 3  # You can adjust this as needed

# Initialize the KMeans model
kmeans = KMeans(n_clusters=num_clusters)

# Fit the KMeans model to the data
kmeans.fit(X)

# Add cluster labels to the concatenated DataFrame
df_concatenated['cluster'] = kmeans.labels_

# Visualize the clusters (assuming you have two features)
plt.figure(figsize=(10, 6))
plt.scatter(df_concatenated['Daily_Return'], df_concatenated['Normalized_Return'], c=df_concatenated['cluster'], cmap='viridis')
plt.title('KMeans Clustering')
plt.xlabel('Daily_Return')
plt.ylabel('Normalized_Return')
plt.colorbar(label='Cluster')
plt.show()

# You can access individual clusters by filtering the DataFrame based on cluster labels
for cluster_label in range(num_clusters):
    cluster_data = df_concatenated[df_concatenated['cluster'] == cluster_label]
    print(f"Cluster {cluster_label}:")
    print(cluster_data)
# Out:
# /tmp/ipykernel_81/1274648373.py:6: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_81/1274648373.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Cluster 0:
# Price             Close         High          Low         Open        Volume  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC         ^GSPC
# Date
# 2008-01-02  1447.160034  1471.770020  1442.069946  1467.969971  3.452650e+09
# 2008-01-03  1447.160034  1456.800049  1443.729980  1447.550049  3.429500e+09
# 2008-01-04  1411.630005  1444.010010  1411.189941  1444.010010  4.166000e+09
# 2008-01-07  1416.180054  1423.869995  1403.449951  1414.069946  4.221260e+09
# 2008-01-08  1390.189941  1430.280029  1388.300049  1415.709961  4.705390e+09
# ...                 ...          ...          ...          ...           ...
# 2022-07-06          NaN          NaN          NaN          NaN           NaN
# 2022-07-12          NaN          NaN          NaN          NaN           NaN
# 2022-07-13          NaN          NaN          NaN          NaN           NaN
# 2022-07-14          NaN          NaN          NaN          NaN           NaN
# 2022-07-15          NaN          NaN          NaN          NaN           NaN
#
# Price      Daily_Return Normalized_Return      Close       High        Low  \
# Ticker                                           XOM        XOM        XOM
# Date
# 2008-01-02    -0.087119          0.742767        NaN        NaN        NaN
# 2008-01-03    -0.013910          0.986090        NaN        NaN        NaN
# 2008-01-04    -0.002446          0.983678        NaN        NaN        NaN
# 2008-01-07    -0.020734          0.963283        NaN        NaN        NaN
# 2008-01-08     0.001160          0.964400        NaN        NaN        NaN
# ...                 ...               ...        ...        ...        ...
# 2022-07-06    -0.029882          1.501538  74.445778  76.188929  72.416579
# 2022-07-12    -0.016320          1.501896  75.536362  76.028021  74.070331
# 2022-07-13    -0.004774          1.494726  75.840302  77.154367  74.463668
# 2022-07-14    -0.018350          1.467298  74.320618  74.472583  72.130513
# 2022-07-15     0.036042          1.520181  75.572105  75.876035  74.106075
#
# Price            Open      Volume cluster
# Ticker            XOM         XOM
# Date
# 2008-01-02        NaN         NaN       0
# 2008-01-03        NaN         NaN       0
# 2008-01-04        NaN         NaN       0
# 2008-01-07        NaN         NaN       0
# 2008-01-08        NaN         NaN       0
# ...               ...         ...     ...
# 2022-07-06  74.874863  33375700.0       0
# 2022-07-12  74.892737  21013000.0       0
# 2022-07-13  74.535177  19928600.0       0
# 2022-07-14  73.167458  26343000.0       0
# 2022-07-15  75.804527  17243700.0       0
#
# [5857 rows x 13 columns]
# Cluster 1:
# Price             Close         High          Low         Open        Volume  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC         ^GSPC
# Date
# 2016-12-08  2246.189941  2251.689941  2237.570068  2241.129883  4.203270e+09
# 2016-12-09  2259.530029  2259.800049  2249.229980  2249.729980  3.886460e+09
# 2016-12-12  2256.959961  2264.030029  2252.370117  2258.830078  4.038850e+09
# 2016-12-13  2271.719971  2277.530029  2263.320068  2263.320068  3.875630e+09
# 2016-12-14  2253.280029  2276.199951  2248.439941  2268.350098  4.409670e+09
# ...                 ...          ...          ...          ...           ...
# 2025-10-07          NaN          NaN          NaN          NaN           NaN
# 2025-10-08          NaN          NaN          NaN          NaN           NaN
# 2025-10-09          NaN          NaN          NaN          NaN           NaN
# 2025-10-10          NaN          NaN          NaN          NaN           NaN
# 2025-10-13          NaN          NaN          NaN          NaN           NaN
#
# Price      Daily_Return Normalized_Return       Close        High         Low  \
# Ticker                                            XOM         XOM         XOM
# Date
# 2016-12-08     0.013756          1.526686         NaN         NaN         NaN
# 2016-12-09     0.003837          1.532545         NaN         NaN         NaN
# 2016-12-12     0.004045          1.538744         NaN         NaN         NaN
# 2016-12-13     0.001988          1.541803         NaN         NaN         NaN
# 2016-12-14     0.002222          1.545229         NaN         NaN         NaN
# ...                 ...               ...         ...         ...         ...
# 2025-10-07     0.006885          2.287556  114.260002  114.510002  111.739998
# 2025-10-08     0.002718          2.293772  114.019997  115.010002  113.410004
# 2025-10-09     0.000437          2.294775  112.910004  115.510002  112.739998
# 2025-10-10    -0.018964          2.251258  110.730003  112.620003  110.709999
# 2025-10-13    -0.006414          2.236819  112.239998  112.300003  111.320000
#
# Price             Open      Volume cluster
# Ticker             XOM         XOM
# Date
# 2016-12-08         NaN         NaN       1
# 2016-12-09         NaN         NaN       1
# 2016-12-12         NaN         NaN       1
# 2016-12-13         NaN         NaN       1
# 2016-12-14         NaN         NaN       1
# ...                ...         ...     ...
# 2025-10-07  114.070000  11945000.0       1
# 2025-10-08  114.379997  12301000.0       1
# 2025-10-09  114.430000  10976200.0       1
# 2025-10-10  112.260002  13811600.0       1
# 2025-10-13  111.540001  10296500.0       1
#
# [2073 rows x 13 columns]
# Cluster 2:
# Price             Close         High          Low         Open        Volume  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC         ^GSPC
# Date
# 2021-03-16  3962.709961  3981.040039  3953.439941  3973.590088  4.613080e+09
# 2021-03-29  3971.090088  3981.830078  3943.250000  3969.310059  4.628180e+09
# 2021-03-31  3972.889893  3994.409912  3966.979980  3967.250000  4.578050e+09
# 2021-04-01  4019.870117  4020.629883  3992.780029  3992.780029  4.162130e+09
# 2021-04-05  4077.909912  4083.419922  4034.439941  4034.439941  4.005030e+09
# ...                 ...          ...          ...          ...           ...
# 2025-10-07  6714.589844  6754.490234  6699.959961  6746.140137  5.546150e+09
# 2025-10-08  6753.720215  6755.640137  6718.089844  6723.870117  5.383130e+09
# 2025-10-09  6735.109863  6764.580078  6716.169922  6760.500000  5.385020e+09
# 2025-10-10  6552.509766  6762.399902  6550.779785  6740.490234  5.385020e+09
# 2025-10-13  6654.720215  6668.680176  6620.709961  6622.529785  5.303960e+09
#
# Price      Daily_Return Normalized_Return Close High Low Open Volume cluster
# Ticker                                      XOM  XOM XOM  XOM    XOM
# Date
# 2021-03-16     0.007768          2.706861   NaN  NaN NaN  NaN    NaN       2
# 2021-03-29     0.013324          2.703945   NaN  NaN NaN  NaN    NaN       2
# 2021-03-31     0.000987          2.702542   NaN  NaN NaN  NaN    NaN       2
# 2021-04-01     0.006435          2.719933   NaN  NaN NaN  NaN    NaN       2
# 2021-04-05     0.010434          2.748312   NaN  NaN NaN  NaN    NaN       2
# ...                 ...               ...   ...  ...  ..  ...    ...     ...
# 2025-10-07     0.001824          4.595557   NaN  NaN NaN  NaN    NaN       2
# 2025-10-08    -0.003301          4.580387   NaN  NaN NaN  NaN    NaN       2
# 2025-10-09     0.005448          4.605339   NaN  NaN NaN  NaN    NaN       2
# 2025-10-10    -0.002960          4.591709   NaN  NaN NaN  NaN    NaN       2
# 2025-10-13    -0.017500          4.511352   NaN  NaN NaN  NaN    NaN       2
#
# [1018 rows x 13 columns]

# %% [markdown]
# ##The code for creating this was originally sourced from plotly.com and then customized for this analysis. It's open source, and you can find licensing details on plotly.com.##
#
# 1. **Please refer to previous section to understand the concept of PCA.  PCA can be used to identify patterns.

# %%
import plotly.express as px
from sklearn.decomposition import PCA

df = df_spx.copy()
features = ["Open", "Close", "Volume"]

pca = PCA()
components = pca.fit_transform(df[features])
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(3),
    color=df["Normalized_Return"]
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %% [markdown]
# ##The code for creating this was originally sourced from plotly.com and then customized for this analysis. It's open source, and you can find licensing details on plotly.com.##
#
# This image is a PCA 3 Dimensional scatterplot of the normalized returns.  It can be interacted with and expanded and contracted to explore the various datapoints.

# %%
from sklearn.decomposition import PCA

df = df_spx.copy()
X = df[['Open', 'Close', 'Volume']]

pca = PCA(n_components=3)
components = pca.fit_transform(X)

total_var = pca.explained_variance_ratio_.sum() * 100

fig = px.scatter_3d(
    components, x=0, y=1, z=2, color=df['Normalized_Return'],
    title=f'Total Explained Variance: {total_var:.2f}%',
    labels={'0': 'PC 1', '1': 'PC 2', '2': 'PC 3'}
)
fig.show()

# %% [markdown]
# ##The code for creating this was originally sourced from plotly.com and then customized for this analysis. It's open source, and you can find licensing details on plotly.com.##
#
# It is a 3 Dimensional surface plot of normalized returns and can be used to visualize the data from a different angle.

# %%
import plotly.graph_objects as go  # Importing Plotly's graph_objects module

# create figure
fig = go.Figure()

# Add surface trace
fig.add_trace(go.Surface(z=df_xom.values.tolist(), colorscale="Viridis"))

# Update plot sizing
fig.update_layout(
    width=800,
    height=900,
    autosize=False,
    margin=dict(t=0, b=0, l=0, r=0),
    template="plotly_white",
)

# Update 3D scene options
fig.update_scenes(
    aspectratio=dict(x=1, y=1, z=0.7),
    aspectmode="manual"
)

# Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "surface"],
                    label="3D Surface",
                    method="restyle"
                ),
                dict(
                    args=["type", "heatmap"],
                    label="Heatmap",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.1,
            yanchor="top"
        ),
    ]
)

# Add annotation
fig.update_layout(
    annotations=[
        dict(text="Trace type:", showarrow=False,
        x=0, y=1.085, yref="paper", align="left")
    ]
)

fig.show()
